# %% [markdown]
# ## Условие 1:
# ### _Оформляйте ноутбук, используя эти советы:_
# #### Номер задачи - **заголовок 2**
# #### Номер подзадачи -**заголовок 3**
# <table>
#     <tr>
#         <td>заголовок 2</td>
#         <td>заголовок 3</td>
#     </tr>
# </table>
#
# ##### - Предоставленные наборы данных оформляйте, как код
# ##### - Рекомендации для преподавателей по оценке задания:
# ###### *Смотреть, чтобы студент красиво оформлял ноутбук, <br>использовал ячейки с текстом, указывал номера заданий*
